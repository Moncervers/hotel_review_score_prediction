# %% [markdown]
# ## Описание проекта
#
# Соревнование по предсказанию пользовательской оценки отелю.
#
# Для оценки используется `MAPE` — средняя абсолютная ошибка в процентах. То есть на какой средний процент прогноз модели отклоняется от фактического значения. Чем **меньше** значение, тем **лучше** работает модель.
# $$
# \text{MAPE} = 100 \cdot \frac{1}{n} \sum_{t=1}^{n} \left| \frac{A_t - F_t}{A_t} \right|
# $$
#
# ### Описание данных
# - **`Hotel_Address`** - Адрес отеля.
# - **`Review_Date`** - Дата публикации отзыва.
# - **`Average_Score`** - Средняя оценка отеля, рассчитанная на основе комментариев за последний год.
# - **`Hotel_Name`** - Название отеля.
# - **`Reviewer_Nationality`** - Национальность рецензента.
# - **`Negative_Review`** - Отрицательный отзыв, оставленный рецензентом отелю. В случае отсутствия заполняется значением `'No Negative'`.
# - **`Review_Total_Negative_Word_Counts`** - Количество слов в отрицательном отзыве.
# - **`Positive_Review`** - Положительный отзыв, оставленный рецензентом отелю. В случае отсутствия заполняется значением `'No Positive'`.
# - **`Review_Total_Positive_Word_Counts`** - Количество слов в положительном отзыве.
# - **`Total_Number_of_Reviews_Reviewer_Has_Given`** - Количество отзывов, написанных рецензентом в прошлом.
# - **`Total_Number_of_Reviews`** - Количество отзывов об отеле.
# - **`Tags`** - Теги, данные рецензентом отелю.
# - **`days_since_review`** - Количество дней между написанием отзыва и чисткой.
# - **`Additional_number_of_soring`** - Средний балл отеля, на основе всех оценок — с текстом отзыва и без.
# - **`lat`** - Широта отеля.
# - **`lng`** - Долгота отеля.
# - **`Reviewer_Score`** - Оценка, данная рецензентом отелю. **Целевая переменная**.

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import ast
from collections import defaultdict

import phik
from optuna_integration import OptunaSearchCV
# import shap
from ipywidgets import IntProgress
from IPython.display import display
import time

from sklearn.metrics import mean_absolute_percentage_error, make_scorer

# Импорт для разбивки и кодирования данных
from sklearn.impute import SimpleImputer
from sklearn.model_selection import (
    # Разбиение данных
    train_test_split,

    # Поиск гиперпараметров
    RandomizedSearchCV
)
from sklearn.preprocessing import (
    # Кодирование числовых значений
    StandardScaler,
    MinMaxScaler,
    RobustScaler,

    # Кодирование категориальных значение
    OneHotEncoder,
    LabelEncoder
)

# Импорт для создания пайплайна
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Импорт бейслайн моделей
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    Lasso
)

# Импорт бустинг моделей
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from optuna.integration import OptunaSearchCV
from optuna.distributions import (
    IntDistribution,
    FloatDistribution,
    CategoricalDistribution
)

from transformers import AutoTokenizer, AutoModel
import torch
from sentence_transformers import SentenceTransformer
import numpy as np
from tqdm.auto import tqdm

RANDOM_STATE = 42

# %% [markdown]
# ## Загрузка и предобработка данных
#
# Загрузим тренировочную и тестовую выборки, после чего приведем их к единому стилю.

# %%
# Загружаем данные
df = pd.read_csv('data/train.csv', parse_dates=['Review_Date'])
test_df = pd.read_csv('data/test.csv', parse_dates=['Review_Date'])

# %%
# Выводим данные о тренировочном датасете
df.describe().T
# Out:
#                                                count  \
# Additional_Number_of_Scoring                412590.0
# Review_Date                                   412590
# Review_Total_Negative_Word_Counts           412590.0
# Total_Number_of_Reviews                     412590.0
# Review_Total_Positive_Word_Counts           412590.0
# Total_Number_of_Reviews_Reviewer_Has_Given  412590.0
# Reviewer_Score                              412590.0
# lat                                         409990.0
# lng                                         409990.0
#
#                                                                      mean  \
# Additional_Number_of_Scoring                                   498.012994
# Review_Date                                 2016-08-13 15:26:43.286555648
# Review_Total_Negative_Word_Counts                               18.551618
# Total_Number_of_Reviews                                       2744.936336
# Review_Total_Positive_Word_Counts                               17.793614
# Total_Number_of_Reviews_Reviewer_Has_Given                       7.166359
# Reviewer_Score                                                   8.395058
# lat                                                             49.440722
# lng                                                              2.826807
#
#                                                             min  \
# Additional_Number_of_Scoring                                1.0
# Review_Date                                 2015-08-04 00:00:00
# Review_Total_Negative_Word_Counts                           0.0
# Total_Number_of_Reviews                                    43.0
# Review_Total_Positive_Word_Counts                           0.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  1.0
# Reviewer_Score                                              2.5
# lat                                                   41.328376
# lng                                                   -0.369758
#
#                                                             25%  \
# Additional_Number_of_Scoring                              169.0
# Review_Date                                 2016-02-23 00:00:00
# Review_Total_Negative_Word_Counts                           2.0
# Total_Number_of_Reviews                                  1161.0
# Review_Total_Positive_Word_Counts                           5.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  1.0
# Reviewer_Score                                              7.5
# lat                                                   48.214277
# lng                                                   -0.143372
#
#                                                             50%  \
# Additional_Number_of_Scoring                              341.0
# Review_Date                                 2016-08-15 00:00:00
# Review_Total_Negative_Word_Counts                           9.0
# Total_Number_of_Reviews                                  2134.0
# Review_Total_Positive_Word_Counts                          11.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  3.0
# Reviewer_Score                                              8.8
# lat                                                   51.499981
# lng                                                    0.019886
#
#                                                             75%  \
# Additional_Number_of_Scoring                              660.0
# Review_Date                                 2017-02-09 00:00:00
# Review_Total_Negative_Word_Counts                          23.0
# Total_Number_of_Reviews                                  3633.0
# Review_Total_Positive_Word_Counts                          22.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  8.0
# Reviewer_Score                                              9.6
# lat                                                   51.516384
# lng                                                    4.834443
#
#                                                             max          std
# Additional_Number_of_Scoring                             2682.0   500.543501
# Review_Date                                 2017-08-03 00:00:00          NaN
# Review_Total_Negative_Word_Counts                         408.0    29.663553
# Total_Number_of_Reviews                                 16670.0  2319.361934
# Review_Total_Positive_Word_Counts                         395.0    21.820234
# Total_Number_of_Reviews_Reviewer_Has_Given                355.0    11.057331
# Reviewer_Score                                             10.0      1.63788
# lat                                                   52.400181     3.468718
# lng                                                   16.429233     4.575712

# %%
# Выводим данные в тренировочном датасете
df
# Out:
#                                             Hotel_Address  \
# 0       Ndsm Plein 28 Amsterdam Noord 1033 WB Amsterda...
# 1       Ferdinand Bolstraat 194 Oud Zuid 1072 LW Amste...
# 2       18 Albert Embankment Lambeth London SE1 7TJ Un...
# 3       Schottenring 24 01 Innere Stadt 1010 Vienna Au...
# 4       Sabino de Arana 22 24 Les Corts 08028 Barcelon...
# ...                                                   ...
# 412585  7 Gracechurch Street City of London London EC3...
# 412586  Westminster Bridge Road Lambeth London SE1 7UT...
# 412587  2 Stanhope Row Park Lane Westminster Borough L...
# 412588  No 1 Seething Lane City of London London EC3N ...
# 412589  4 Bryanston St Marble Arch Westminster Borough...
#
#         Additional_Number_of_Scoring Review_Date  \
# 0                                170  2017-04-17
# 1                                114  2016-05-26
# 2                               1195  2016-12-04
# 3                                111  2017-04-30
# 4                                147  2017-01-22
# ...                              ...         ...
# 412585                           764  2017-03-31
# 412586                          2623  2017-05-19
# 412587                           444  2015-12-07
# 412588                           623  2017-04-16
# 412589                           255  2016-06-14
#
#                                              Hotel_Name Reviewer_Nationality  \
# 0       DoubleTree by Hilton Hotel Amsterdam NDSM Wharf      United Kingdom
# 1                                 Savoy Hotel Amsterdam            Malaysia
# 2                           Park Plaza London Riverbank      United Kingdom
# 3                        Palais Hansen Kempinski Vienna                Oman
# 4                                   Catalonia Rigoletto      United Kingdom
# ...                                                 ...                  ...
# 412585                  Club Quarters Hotel Gracechurch             Belgium
# 412586             Park Plaza Westminster Bridge London      United Kingdom
# 412587                             Park Lane Mews Hotel      United Kingdom
# 412588                        Apex City Of London Hotel      United Kingdom
# 412589    DoubleTree by Hilton Hotel London Marble Arch            Malaysia
#
#                                           Negative_Review  \
# 0        Too far from attractions Had to use ferry to ...
# 1        Staff should handle customer document during ...
# 2        The hot breakfast could have been fresher tas...
# 3        You have to pay the full amount before arrivi...
# 4                                                All Good
# ...                                                   ...
# 412585   Most of the coffee shops around the hotel are...
# 412586                               Bar rather expensive
# 412587   Lack of ironing facilities Asked for iron to ...
# 412588   Having stayed at this hotel a number of times...
# 412589   The mattress was too soft Both of us are pron...
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                      72                     1593
# 1                                     246                      995
# 2                                      19                     4684
# 3                                      14                      865
# 4                                       3                     1562
# ...                                   ...                      ...
# 412585                                 24                     2996
# 412586                                  4                    12158
# 412587                                 21                     2061
# 412588                                 29                     2750
# 412589                                 22                     1290
#
#                                           Positive_Review  \
# 0                 Staff were very helpful Good breakfast
# 1        Very clean and cozy room Friendly and helpful...
# 2        The room was to a high standard The staff wer...
# 3                               Everything was excellent
# 4        The location was excellent for visiting the N...
# ...                                                   ...
# 412585   Good location at walking distance to metro st...
# 412586   Location and quality of the go Room was a gre...
# 412587           Excellent location comfortable and clean
# 412588   All the staff where very friendly helpful Hot...
# 412589                                        No Positive
#
#         Review_Total_Positive_Word_Counts  \
# 0                                       8
# 1                                      41
# 2                                      19
# 3                                       5
# 4                                      11
# ...                                   ...
# 412585                                 75
# 412586                                 17
# 412587                                  6
# 412588                                 41
# 412589                                  0
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                                1             5.4
# 1                                                1             9.6
# 2                                                3             8.8
# 3                                               21            10.0
# 4                                                1             9.2
# ...                                            ...             ...
# 412585                                          28             9.2
# 412586                                           4            10.0
# 412587                                           1             7.9
# 412588                                           4             8.3
# 412589                                           5             7.9
#
#                                                      Tags days_since_review  \
# 0       [' Leisure trip ', ' Couple ', ' Queen Guest R...           108 day
# 1       [' Leisure trip ', ' Couple ', ' Small Double ...           434 day
# 2       [' Business trip ', ' Solo traveler ', ' Super...           242 day
# 3       [' Leisure trip ', ' Couple ', ' Deluxe Room '...           95 days
# 4       [' Leisure trip ', ' Family with young childre...           193 day
# ...                                                   ...               ...
# 412585  [' Leisure trip ', ' Couple ', ' Small Queen R...           125 day
# 412586  [' Leisure trip ', ' Family with young childre...           76 days
# 412587  [' Business trip ', ' Solo traveler ', ' Doubl...           605 day
# 412588  [' Leisure trip ', ' Couple ', ' City King or ...           109 day
# 412589  [' Leisure trip ', ' Couple ', ' Standard Quee...           415 day
#
#               lat        lng
# 0       52.400181   4.893665
# 1       52.349743   4.891191
# 2       51.491374  -0.121419
# 3       48.216315  16.368510
# 4       41.385817   2.125679
# ...           ...        ...
# 412585  51.512796  -0.084797
# 412586  51.500961  -0.116591
# 412587  51.505933  -0.148942
# 412588  51.510462  -0.079550
# 412589  51.514573  -0.156660
#
# [412590 rows x 16 columns]

# %%
# Выделяем год месяц и день
df['review_year'] = df['Review_Date'].dt.year
df['review_month'] = df['Review_Date'].dt.month
df['review_day'] = df['Review_Date'].dt.day

# Преобразуем столбец с днями в числовой
df['days_since_review'] = df['days_since_review'].apply(lambda x: x.split()[0]).astype('int64')
df['days_since_review'].head()
# Out:
# 0    108
# 1    434
# 2    242
# 3     95
# 4    193
# Name: days_since_review, dtype: int64

# %%
# Выводим данные о тестовом датасете
test_df.describe().T
# Out:
#                                                count  \
# Additional_Number_of_Scoring                103148.0
# Review_Date                                   103148
# Review_Total_Negative_Word_Counts           103148.0
# Total_Number_of_Reviews                     103148.0
# Review_Total_Positive_Word_Counts           103148.0
# Total_Number_of_Reviews_Reviewer_Has_Given  103148.0
# lat                                         102480.0
# lng                                         102480.0
#
#                                                                      mean  \
# Additional_Number_of_Scoring                                   498.357205
# Review_Date                                 2016-08-13 05:11:12.478380544
# Review_Total_Negative_Word_Counts                                18.49078
# Total_Number_of_Reviews                                       2738.974396
# Review_Total_Positive_Word_Counts                               17.707837
# Total_Number_of_Reviews_Reviewer_Has_Given                       7.164569
# lat                                                              49.44931
# lng                                                              2.811787
#
#                                                             min  \
# Additional_Number_of_Scoring                                1.0
# Review_Date                                 2015-08-04 00:00:00
# Review_Total_Negative_Word_Counts                           0.0
# Total_Number_of_Reviews                                    43.0
# Review_Total_Positive_Word_Counts                           0.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  1.0
# lat                                                   41.328376
# lng                                                   -0.369758
#
#                                                             25%  \
# Additional_Number_of_Scoring                              169.0
# Review_Date                                 2016-02-22 00:00:00
# Review_Total_Negative_Word_Counts                           2.0
# Total_Number_of_Reviews                                  1164.0
# Review_Total_Positive_Word_Counts                           5.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  1.0
# lat                                                   48.214662
# lng                                                   -0.143671
#
#                                                             50%  \
# Additional_Number_of_Scoring                              341.5
# Review_Date                                 2016-08-15 00:00:00
# Review_Total_Negative_Word_Counts                           9.0
# Total_Number_of_Reviews                                  2134.0
# Review_Total_Positive_Word_Counts                          11.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  3.0
# lat                                                   51.500198
# lng                                                    -0.00025
#
#                                                             75%  \
# Additional_Number_of_Scoring                              660.0
# Review_Date                                 2017-02-09 00:00:00
# Review_Total_Negative_Word_Counts                          23.0
# Total_Number_of_Reviews                                  3611.0
# Review_Total_Positive_Word_Counts                          22.0
# Total_Number_of_Reviews_Reviewer_Has_Given                  8.0
# lat                                                   51.516288
# lng                                                    4.820783
#
#                                                             max          std
# Additional_Number_of_Scoring                             2682.0   500.520661
# Review_Date                                 2017-08-03 00:00:00          NaN
# Review_Total_Negative_Word_Counts                         403.0    29.799785
# Total_Number_of_Reviews                                 16670.0  2309.866121
# Review_Total_Positive_Word_Counts                         383.0    21.739841
# Total_Number_of_Reviews_Reviewer_Has_Given                297.0    10.971602
# lat                                                   52.400181     3.456744
# lng                                                   16.429233     4.594254

# %%
# Выводим данные в тестовом датасете
test_df
# Out:
#                                             Hotel_Address  \
# 0       7 Western Gateway Royal Victoria Dock Newham L...
# 1       Great Cumberland Place Westminster Borough Lon...
# 2        14 Rue de la Sorbonne 5th arr 75005 Paris France
# 3       4 Broad Court Bow Street Covent Garden Westmin...
# 4       79 81 avenue du Maine 14th arr 75014 Paris France
# ...                                                   ...
# 103143  Via Napo Torriani 18 Central Station 20124 Mil...
# 103144  97 Great Russell Street Bloomsbury Camden Lond...
# 103145  Oosterdoksstraat 4 Amsterdam City Center 1011 ...
# 103146  St Katherines Way Tower Hamlets London E1W 1LD...
# 103147  No 1 Seething Lane City of London London EC3N ...
#
#         Additional_Number_of_Scoring Review_Date  \
# 0                                359  2015-08-14
# 1                               1190  2017-08-03
# 2                                 37  2016-04-27
# 3                                294  2016-03-03
# 4                                201  2016-05-02
# ...                              ...         ...
# 103143                           384  2016-12-01
# 103144                           406  2017-07-03
# 103145                           803  2015-11-24
# 103146                           950  2016-09-01
# 103147                           623  2015-11-02
#
#                                               Hotel_Name Reviewer_Nationality  \
# 0                                   Novotel London Excel      United Kingdom
# 1                          The Cumberland A Guoman Hotel           Gibraltar
# 2       Hotel Mercure La Sorbonne Saint Germain des Pr s      United Kingdom
# 3                                         Fielding Hotel      United Kingdom
# 4                    Holiday Inn Paris Gare Montparnasse           Australia
# ...                                                  ...                  ...
# 103143                                       Hotel Berna      United Kingdom
# 103144                 Radisson Blu Edwardian Kenilworth           Australia
# 103145   DoubleTree by Hilton Amsterdam Centraal Station      United Kingdom
# 103146                          The Tower A Guoman Hotel      United Kingdom
# 103147                         Apex City Of London Hotel            Portugal
#
#                                           Negative_Review  \
# 0                                             No Negative
# 1                                             No Negative
# 2        The beds were uncomfortable We requested a do...
# 3                                            No negatives
# 4              Not having subtitles on the TV in english
# ...                                                   ...
# 103143                                        No Negative
# 103144   I would love to have been able to turn the ai...
# 103145                             A little bit expensive
# 103146                      nothing everything was great
# 103147   Beware than inspite of the central location o...
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                       0                     1158
# 1                                       0                     5180
# 2                                      31                      464
# 3                                       3                     1271
# 4                                      10                     3228
# ...                                   ...                      ...
# 103143                                  0                     4017
# 103144                                 26                     2011
# 103145                                  5                     3911
# 103146                                  6                     3486
# 103147                                 44                     2750
#
#                                           Positive_Review  \
# 0        Excellent location for Excel centre Friendly ...
# 1        The location was excellent rieally good next ...
# 2        The buffet breakfast was excellent The breakf...
# 3        Beautifully appointed room and incredibly pla...
# 4        Close to transport shops resturants and attra...
# ...                                                   ...
# 103143    Excellent friendly staff great breakfast buffet
# 103144   The staff were helpful and friendly Breakfast...
# 103145    Everything location room staff food and parking
# 103146   I stay at this hotel every time we stay in Lo...
# 103147   Excellent hotel full of little details Lovely...
#
#         Review_Total_Positive_Word_Counts  \
# 0                                      14
# 1                                      11
# 2                                      22
# 3                                      19
# 4                                      18
# ...                                   ...
# 103143                                  7
# 103144                                 89
# 103145                                  8
# 103146                                 50
# 103147                                 34
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  \
# 0                                                5
# 1                                                2
# 2                                                1
# 3                                               12
# 4                                                2
# ...                                            ...
# 103143                                           5
# 103144                                           4
# 103145                                           1
# 103146                                           1
# 103147                                           9
#
#                                                      Tags days_since_review  \
# 0       [' Leisure trip ', ' Family with young childre...           720 day
# 1       [' Leisure trip ', ' Group ', ' Standard Doubl...            0 days
# 2       [' Leisure trip ', ' Couple ', ' Standard Doub...           463 day
# 3       [' Leisure trip ', ' Couple ', ' Double Room '...           518 day
# 4       [' Leisure trip ', ' Couple ', ' Twin Room Non...           458 day
# ...                                                   ...               ...
# 103143  [' Leisure trip ', ' Solo traveler ', ' Qualit...           245 day
# 103144  [' Leisure trip ', ' Group ', ' Standard Doubl...           31 days
# 103145  [' Leisure trip ', ' Couple ', ' Executive Que...           618 day
# 103146  [' Leisure trip ', ' Couple ', ' Standard Doub...           336 day
# 103147  [' Leisure trip ', ' Solo traveler ', ' City K...           640 day
#
#               lat       lng
# 0       51.507720  0.022981
# 1       51.514879 -0.160650
# 2       48.849350  2.343057
# 3       51.513931 -0.121989
# 4       48.838292  2.323019
# ...           ...       ...
# 103143  45.482669  9.203437
# 103144  51.517972 -0.128050
# 103145  52.376752  4.904618
# 103146  51.506472 -0.071689
# 103147  51.510462 -0.079550
#
# [103148 rows x 15 columns]

# %%
# Выделяем год месяц и день
test_df['review_year'] = test_df['Review_Date'].dt.year
test_df['review_month'] = test_df['Review_Date'].dt.month
test_df['review_day'] = test_df['Review_Date'].dt.day

test_df['days_since_review'] = test_df['days_since_review'].apply(lambda x: x.split()[0]).astype('int64')
test_df['days_since_review'].head()
# Out:
# 0    720
# 1      0
# 2    463
# 3    518
# 4    458
# Name: days_since_review, dtype: int64

# %%
# Проверяем, совпадают ли все столбцы в датасетах
set(df.columns) - set(test_df.columns)
# Out:
# {'Reviewer_Score'}

# %%
# Переименовываем столбцы в тренировочном датасете
df = df.rename(columns={
    'Hotel_Address': 'address',
    'Review_Date': 'review_date',
    'Average_Score': 'avg_hotel_score',
    'Hotel_Name': 'hotel',
    'Reviewer_Nationality': 'nationality',
    'Negative_Review': 'negative_review',
    'Review_Total_Negative_Word_Counts': 'negative_words',
    'Positive_Review': 'positive_review',
    'Review_Total_Positive_Word_Counts': 'positive_words',
    'Total_Number_of_Reviews_Reviewer_Has_Given': 'total_reviews',
    'Total_Number_of_Reviews': 'hotel_review_count',
    'Tags': 'tags',
    'days_since_review': 'days_since_review',
    'Additional_Number_of_Scoring': 'avg_scoring_rating',
    'lat': 'latitude',
    'lng': 'longitude',
    'Reviewer_Score': 'score'  # Целевая переменная
})

# Проверяем, корректно ли мы все переименовали
df.columns
# Out:
# Index(['address', 'avg_scoring_rating', 'review_date', 'hotel', 'nationality',
#        'negative_review', 'negative_words', 'hotel_review_count',
#        'positive_review', 'positive_words', 'total_reviews', 'score', 'tags',
#        'days_since_review', 'latitude', 'longitude', 'review_year',
#        'review_month', 'review_day'],
#       dtype='object')

# %%
# Переименовываем столбцы в тренировочном датасете
test_df = test_df.rename(columns={
    'Hotel_Address': 'address',
    'Review_Date': 'review_date',
    'Average_Score': 'avg_hotel_score',
    'Hotel_Name': 'hotel',
    'Reviewer_Nationality': 'nationality',
    'Negative_Review': 'negative_review',
    'Review_Total_Negative_Word_Counts': 'negative_words',
    'Positive_Review': 'positive_review',
    'Review_Total_Positive_Word_Counts': 'positive_words',
    'Total_Number_of_Reviews_Reviewer_Has_Given': 'total_reviews',
    'Total_Number_of_Reviews': 'hotel_review_count',
    'Tags': 'tags',
    'days_since_review': 'days_since_review',
    'Additional_Number_of_Scoring': 'avg_scoring_rating',
    'lat': 'latitude',
    'lng': 'longitude',
})

# Проверяем, корректно ли мы все переименовали
test_df.columns
# Out:
# Index(['address', 'avg_scoring_rating', 'review_date', 'hotel', 'nationality',
#        'negative_review', 'negative_words', 'hotel_review_count',
#        'positive_review', 'positive_words', 'total_reviews', 'tags',
#        'days_since_review', 'latitude', 'longitude', 'review_year',
#        'review_month', 'review_day'],
#       dtype='object')

# %% [markdown]
# ### Вывод
#
# Мы загрузили данные, переименовали столбцы, приведя их к единому стилю. Теперь столбцы выглядят так:
# - **`address`** - Адрес отеля.
# - **`review_date`** - Дата публикации отзыва.
# - **`avg_hotel_score`** - Средняя оценка отеля, рассчитанная на основе комментариев за последний год.
# - **`hotel`** - Название отеля.
# - **`nationality`** - Национальность рецензента.
# - **`negative_review`** - Отрицательный отзыв, оставленный рецензентом отелю. В случае отсутствия заполняется значением `'No Negative'`.
# - **`negative_words`** - Количество слов в отрицательном отзыве.
# - **`positive_review`** - Положительный отзыв, оставленный рецензентом отелю. В случае отсутствия заполняется значением `'No Positive'`.
# - **`positive_words`** - Количество слов в положительном отзыве.
# - **`total_reviews`** - Количество отзывов, написанных рецензентом в прошлом.
# - **`hotel_review_count`** - Общее количество отзывов об отеле.
# - **`tags`** - Теги, данные рецензентом отелю.
# - **`days_since_review`** - Количество дней между написанием отзыва и текущей датой (или 'чисткой').
# - **`avg_scoring_rating`** - Средний балл отеля, рассчитанный на основе всех оценок — как с текстом отзыва, так и без него.
# - **`latitude`** - Широта местоположения отеля.
# - **`longitude`** - Долгота местоположения отеля.
# - **`score`** - Оценка, данная рецензентом отелю. **Целевая переменная**.

# %% [markdown]
# ## Предобработка данных
#
# Проверим данные на распределения, на наличие пропусков, явных и неявных дубликатов. Для этого определим числовые и категориальные столбцы

# %%
# Числовые столбцы
num_cols = ['avg_scoring_rating', 'score',
            'negative_words', 'positive_words',
            'hotel_review_count', 'total_reviews']

# Категориальные столбцы
cat_cols = ['address', 'hotel', 'nationality', 'negative_review', 'positive_review', 'tags']

# Столбцы с датой
date_cols = ['days_since_review', 'review_year', 'review_month', 'review_day']

# %%
df.isna().sum()
# Out:
# address                  0
# avg_scoring_rating       0
# review_date              0
# hotel                    0
# nationality              0
# negative_review          0
# negative_words           0
# hotel_review_count       0
# positive_review          0
# positive_words           0
# total_reviews            0
# score                    0
# tags                     0
# days_since_review        0
# latitude              2600
# longitude             2600
# review_year              0
# review_month             0
# review_day               0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# address                 0
# avg_scoring_rating      0
# review_date             0
# hotel                   0
# nationality             0
# negative_review         0
# negative_words          0
# hotel_review_count      0
# positive_review         0
# positive_words          0
# total_reviews           0
# tags                    0
# days_since_review       0
# latitude              668
# longitude             668
# review_year             0
# review_month            0
# review_day              0
# dtype: int64

# %% [markdown]
# Мы видим, что у нас пропуски только в столбцах с шириной и долготой отеля. Оставим все как есть, так как скорее всего эти признаки не будут влиять на модель. Теперь посмотрим на наличия явных дубликатов

# %% [markdown]
# ### Предобработка дубликатов
#
# Проверим датасеты на наличие явных и неявных дубликатов

# %%
df.duplicated().sum()
# Out:
# np.int64(354)

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# У нас было 354 явных дубликата, мы их удалили, теперь посмотрим на неявные дубликаты

# %%
# Смотрим количество уникальных значений в категориальных столбцах
df[cat_cols].nunique()
# Out:
# address              1493
# hotel                1492
# nationality           223
# negative_review    265265
# positive_review    332006
# tags                48842
# dtype: int64

# %%
test_df[cat_cols].nunique()
# Out:
# address             1490
# hotel               1489
# nationality          201
# negative_review    67891
# positive_review    85213
# tags               21622
# dtype: int64

# %% [markdown]
# Выгрузим столбцы, в которых потенциально могут быть неявные дубликаты и используем ИИ для проверки на неявные дубликаты, так как в данных столбцах слишком много уникальных значений, чтобы проверять их вручную.

# %%
# Выгружаем столбцы тренировочного датасет
pd.DataFrame(df['address'].unique()).to_csv('text_files/address.txt', index=False, header=False)
pd.DataFrame(df['hotel'].unique()).to_csv('text_files/hotel.txt', index=False, header=False)
pd.DataFrame(df['nationality'].unique()).to_csv('text_files/nationality.txt', index=False, header=False)

# %% [markdown]
# #### Обработка неявных дубликатов
#
# Удалось определить следующие неявные дубликаты в столбце `hotel`:
#  - Best Western Premier Le Swann — Best Western Le Jardin de Cluny
#  - NH Collection Amsterdam Doelen — NH Amsterdam Doelen
#  - Catalonia Atenas  — Catalonia Diagonal Centro
#  - Hotel Mercure Wien City — Mercure Vienna First
#  - H tel Saint Paul Rive Gauche — Hotel Saint Paul Rive Gauche
#  - Le Pradey — Le Pradet
#  - Hotel Wagner — Hotel Wagner Vienna
#
# В столбце `nationality` были найдены следующие неявные дубликаты:
#  - Abkhazia Georgia — Georgia
#  - East Timor — Timor Leste
#  - Cocos K I — Cocos (Keeling) Islands
#  - St Martin — Saint Martin
#  - Turks Caicos Islands — Turks and Caicos Islands
#  - Myanmar — Burma
#  - South Korea — Korea South
#  - Russia — Russian Federation
#  - Iran — Iran Islamic Republic
#  - Syria — Syrian Arab Republic
#  - Venezuela — Venezuela RB
#  - North Macedonia — Macedonia
#  - Congo — Congo Republic
#  - Laos — Lao PDR
#  - Vietnam — Viet Nam
#  - Yemen — Yemen Arab Republic
#  - Tanzania — Tanzania United Republic
#  - Egypt — Egypt Arab Republic
#  - Brunei — Brunei Darussalam
#  - Bahamas — Bahamas The
#  - Gambia — Gambia The
#  - Fiji — Fiji Islands
#  - Malta — Republic of Malta
#  - Qatar — State of Qatar
#  - Kuwait — State of Kuwait
#  - Mauritius — Republic of Mauritius
#  - Somalia — Somali Republic
#  - Nepal — Federal Democratic Republic of Nepal
#  - Honduras — Republic of Honduras
#  - Jamaica — Jamaica Island
#  - Cyprus — Republic of Cyprus
#  - Lebanon — Lebanese Republic
#  - Slovenia — Republic of Slovenia
#  - Serbia — Republic of Serbia
#  - Croatia — Republic of Croatia
#  - Bulgaria — Republic of Bulgaria
#  - Romania — Romanian
#  - Azerbaijan — Azerbaijan Republic
#  - Armenia — Republic of Armenia
#  - Moldova — Republic of Moldova
#
# Удостоверимся, что в названии отеля неявные дубликаты, а не ошибка. С некоторыми названиями очевидно, однако некоторые могут быть действительно разными отелями

# %%
# Объявляем список дубликатов в отелях
implicit_duplicates = [
    ['Best Western Premier Le Swann',
     'Best Western Le Jardin de Cluny'],
    ['NH Collection Amsterdam Doelen',
     'NH Amsterdam Doelen'],
    ['Catalonia Atenas',
     'Catalonia Diagonal Centro'],
    ['Hotel Mercure Wien City',
     'Mercure Vienna First'],
    ['H tel Saint Paul Rive Gauche',
     'Hotel Saint Paul Rive Gauche'],
    ['Le Pradey',
     'Le Pradet'],
    ['Hotel Wagner',
     'Hotel Wagner Vienna']]

# Выводим информацию о паре отелей и адресах этих отелей
for i, pair in enumerate(implicit_duplicates):
    print(f'Pair: {pair}\n'
          f'Unique addresses: {df[df['hotel'].isin(pair)]['address'].unique()}\n\n')
# Out:
# Pair: ['Best Western Premier Le Swann', 'Best Western Le Jardin de Cluny']
# Unique addresses: ['9 Rue du Sommerard 5th arr 75005 Paris France'
#  '15 rue de Constantinople 8th arr 75008 Paris France']
#
#
# Pair: ['NH Collection Amsterdam Doelen', 'NH Amsterdam Doelen']
# Unique addresses: ['Nieuwe Doelenstraat 24 Amsterdam City Center 1012 CP Amsterdam Netherlands']
#
#
# Pair: ['Catalonia Atenas', 'Catalonia Diagonal Centro']
# Unique addresses: ['Avenida Meridiana 151 Sant Mart 08026 Barcelona Spain'
#  'Balmes 142 146 Eixample 08008 Barcelona Spain']
#
#
# Pair: ['Hotel Mercure Wien City', 'Mercure Vienna First']
# Unique addresses: ['Hollandstra e 3 02 Leopoldstadt 1020 Vienna Austria'
#  'Desider Friedmann Platz 2 01 Innere Stadt 1010 Vienna Austria']
#
#
# Pair: ['H tel Saint Paul Rive Gauche', 'Hotel Saint Paul Rive Gauche']
# Unique addresses: ['43 rue Monsieur le Prince 6th arr 75006 Paris France']
#
#
# Pair: ['Le Pradey', 'Le Pradet']
# Unique addresses: ['5 Rue Saint Roch 1st arr 75001 Paris France']
#
#
# Pair: ['Hotel Wagner', 'Hotel Wagner Vienna']
# Unique addresses: ['Via M Buonarroti 13 Fiera Milano City 20149 Milan Italy']

# %% [markdown]
# В конечном итоге у нас всего 4 пары отелей, которые являются неявными дубликатами:
#  - NH Collection Amsterdam Doelen — NH Amsterdam Doelen
#  - H tel Saint Paul Rive Gauche — Hotel Saint Paul Rive Gauche
#  - Le Pradey — Le Pradet
#  - Hotel Wagner — Hotel Wagner Vienna
#
# Преобразуем неявные дубликаты в столбце с отелем и национальностью

# %%
# Словари для неявных дубликатов
hotel_mapping = {
    'NH Collection Amsterdam Doelen': 'NH Amsterdam Doelen',
    'H tel Saint Paul Rive Gauche': 'Hotel Saint Paul Rive Gauche',
    'Le Pradey': 'Le Pradet',
    'Hotel Wagner': 'Hotel Wagner Vienna',
}

nationality_mapping = {
    'Abkhazia Georgia': 'Georgia',
    'East Timor': 'Timor Leste',
    'Cocos K I': 'Cocos (Keeling) Islands',
    'St Martin': 'Saint Martin',
    'Turks Caicos Islands': 'Turks and Caicos Islands',
    'Myanmar': 'Burma',
    'South Korea': 'Korea South',
    'Russia': 'Russian Federation',
    'Iran': 'Iran Islamic Republic',
    'Syria': 'Syrian Arab Republic',
    'Venezuela': 'Venezuela RB',
    'North Macedonia': 'Macedonia',
    'Congo': 'Congo Republic',
    'Laos': 'Lao PDR',
    'Vietnam': 'Viet Nam',
    'Yemen': 'Yemen Arab Republic',
    'Tanzania': 'Tanzania United Republic',
    'Egypt': 'Egypt Arab Republic',
    'Brunei': 'Brunei Darussalam',
    'Bahamas': 'Bahamas The',
    'Gambia': 'Gambia The',
    'Fiji': 'Fiji Islands',
    'Malta': 'Republic of Malta',
    'Qatar': 'State of Qatar',
    'Kuwait': 'State of Kuwait',
    'Mauritius': 'Republic of Mauritius',
    'Somalia': 'Somali Republic',
    'Nepal': 'Federal Democratic Republic of Nepal',
    'Honduras': 'Republic of Honduras',
    'Jamaica': 'Jamaica Island',
    'Cyprus': 'Republic of Cyprus',
    'Lebanon': 'Lebanese Republic',
    'Slovenia': 'Republic of Slovenia',
    'Serbia': 'Republic of Serbia',
    'Croatia': 'Republic of Croatia',
    'Bulgaria': 'Republic of Bulgaria',
    'Romania': 'Romanian',
    'Azerbaijan': 'Azerbaijan Republic',
    'Armenia': 'Republic of Armenia',
    'Moldova': 'Republic of Moldova'
}

# Приводим неявные дубликаты к единому формату
df['hotel'] = df['hotel'].replace(hotel_mapping)
df['nationality'] = df['nationality'].replace(nationality_mapping)

# Приводим к такому же типу данные в тестовом датасете
test_df['hotel'] = test_df['hotel'].replace(hotel_mapping)
test_df['nationality'] = test_df['nationality'].replace(nationality_mapping)

# %%
# Смотрим, есть ли в тестовом датасете отели, которых нет в тренировочном
set(test_df['hotel']) - set(df['hotel'])
# Out:
# set()

# %%
# Смотрим, есть ли в тестовом датасете национальности, которых нет в тренировочном
set(test_df['nationality']) - set(df['nationality'])
# Out:
# {' Equatorial Guinea ',
#  ' Northern Mariana Islands ',
#  ' Palau ',
#  ' Svalbard Jan Mayen '}

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Предобработка числовых столбцов
# Обработаем числовые столбцы, посмотрим на выбросы в них и их распределения

# %%
plt.figure(figsize=(12, 8))

# Выводим гистограмму по данным
for i, col in enumerate(num_cols):
    plt.subplot(3, 2, i + 1)
    plt.hist(df[col], bins=20)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Мы видим, что у нас почти во всех столбцах есть выбросы около нуля, ничего экстраординарного. Интерес вызывает только столбец `score`, так как 'провал' в значении '6'. У нас проблема

# %% [markdown]
# #### Предобработка выбросов
#
# Когда мы выводили гистограммы, мы увидели, что там присутствуют выбросы, посмотрим на них подробнее

# %%
plt.figure(figsize=(12, 8))

# Выводим диаграммы размаха
for i, col in enumerate(num_cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(x=col, data=df)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Мы так же видим, что у нас присутствуют выбросы, но они в пределах 'нормы'. Никаких сверхбольших значений не наблюдаем, скорее всего это просто единичные большие отели. Возможно, стоит удалить отели, у которых больше 8000 отзывов. Это единичные случаи, которые могут помешать модели уловить закономерность. Нужно посмотреть, какое количество записей с отелями, у которых много отзывов

# %%
print('Процент выбросов от общего числа данных',
      (df[df['hotel_review_count'] >= 8000]['hotel'].count() / df.shape[0]) * 100)

df[df['hotel_review_count'] >= 8000]['hotel'].count()
# Out:
# Процент выбросов от общего числа данных 3.499694349838442
# np.int64(14427)

# %% [markdown]
# Выбросы составляют всего 3.5% от общего числа данных, однако это все равно достаточное большое количество данных (14 000) записей. Это позволит модели обучиться и уловить закономерности, потому оставим данные выбросы

# %%
plt.figure(figsize=(12, 8))

for i, col in enumerate(date_cols[1:]):
    plt.subplot(3, 1, i + 1)
    sns.countplot(x=col, data=df)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Мы видим, что все данные у нас распределены почти равномерно. Можно только выделить, что в 2015-м году было очень мало отзывов в сравнении с 2016-м и 2017-м годами

# %% [markdown]
# ### Предобработка категориальных столбцов.
#
# У нас есть столбец с метками, которые были в заказе пользователя. Выделим все метки и проставим

# %%
# Функции для выделения тегов

def normalize_tags(tag_str, separator='|'):
    """
    Преобразует строковое представление списка тегов в одну строку с разделителем.

    Пример:
    Вход: '[\' Business trip \', \' Solo traveler \', ...]'
    Выход: 'Business trip|Solo traveler|...'
    """
    try:
        # Безопасно преобразуем строку в список
        raw_list = ast.literal_eval(tag_str)
        # Очищаем теги от лишних пробелов и объединяем в строку
        cleaned_tags = [tag.strip() for tag in raw_list]
        return separator.join(cleaned_tags)
    except (SyntaxError, ValueError) as e:
        print(f'Ошибка обработки строки: {e}')
        return ''  # Возвращаем пустую строку при ошибке


def parse_tag(tag):
    """
    Парсит отдельный тег и возвращает словарь с категориями.
    """
    tag = tag.strip()
    result = {}

    # Питомцы
    if tag == 'With a pet':
        return {'pets': 1}

    # Тип поездки
    if tag in ['Business trip', 'Leisure trip']:
        return {'trip_type': tag}

    # Тип путешественника
    traveler_types = [
        'Solo traveler', 'Couple', 'Group',
        'Family with young children', 'Family with older children',
        'Travelers with friends'
    ]
    if tag in traveler_types:
        return {'traveler_type': tag}

    # Длительность пребывания
    stay_match = re.match(r'Stayed (\d+) night[s]?', tag)
    if stay_match:
        return {'stay_duration_days': int(stay_match.group(1))}

    # Устройство отправки
    device_match = re.match(r'Submitted from a (mobile|desktop|tablet) device', tag)
    if device_match:
        return {'submission_device': device_match.group(1)}

    # Количество комнат
    room_count_match = re.match(r'(\d+) rooms?', tag)
    if room_count_match:
        return {'room_count': int(room_count_match.group(1))}

    # Тип номера
    if 'room' in tag.lower() or 'studio' in tag.lower() or 'suite' in tag.lower():
        return {'room_type': tag}

    # Неизвестный тег
    return {'unknown_tag': tag}


def parse_tags(df, column_name):
    """
    Обрабатывает теги в указанном столбце DataFrame и добавляет новые столбцы.

    Аргументы:
        df (pd.DataFrame): Исходный DataFrame.
        column_name (str): Имя столбца с тегами.

    Возвращает:
        pd.DataFrame: Обновленный DataFrame с новыми столбцами.
    """
    # Проверка наличия столбца
    if column_name not in df.columns:
        raise ValueError(f'Столбец {column_name} отсутствует в DataFrame.')

    # Копия DataFrame для избежания изменения оригинала
    df = df.copy()

    def process_row(row):
        line = row[column_name]

        # Разделение тегов
        if '|' in line:
            tags = [t.strip() for t in line.split('|')]
        else:
            try:
                tags = [t.strip() for t in eval(line)]
            except:
                tags = []

        # Инициализация результата
        result = defaultdict(lambda: None, {'pets': 0})

        for tag in tags:
            parsed = parse_tag(tag)
            for key, value in parsed.items():
                if key == 'pets':
                    result[key] = 1 if value == 1 else result[key]
                elif key == 'unknown_tag':
                    continue
                else:
                    result[key] = value

        return pd.Series(result)

    # Применение к каждой строке
    new_columns = df.apply(process_row, axis=1)

    # Объединение с оригинальным DataFrame
    df = pd.concat([df, new_columns], axis=1)

    return df

# %%
# Выделяем теги из тренировочного датасета
df['tags'] = df['tags'].apply(normalize_tags)
df = parse_tags(df, 'tags')

# Выделяем теги из тестового датасета
test_df['tags'] = test_df['tags'].apply(normalize_tags)
test_df = parse_tags(test_df, 'tags')

print('Train DataFrame columns:', df.columns, end='\n\n')
print('Test DataFrame columns:', test_df.columns)
# Out:
# Train DataFrame columns: Index(['address', 'avg_scoring_rating', 'review_date', 'hotel', 'nationality',
#        'negative_review', 'negative_words', 'hotel_review_count',
#        'positive_review', 'positive_words', 'total_reviews', 'score', 'tags',
#        'days_since_review', 'latitude', 'longitude', 'review_year',
#        'review_month', 'review_day', 'pets', 'room_count', 'room_type',
#        'stay_duration_days', 'submission_device', 'traveler_type',
#        'trip_type'],
#       dtype='object')
#
# Test DataFrame columns: Index(['address', 'avg_scoring_rating', 'review_date', 'hotel', 'nationality',
#        'negative_review', 'negative_words', 'hotel_review_count',
#        'positive_review', 'positive_words', 'total_reviews', 'tags',
#        'days_since_review', 'latitude', 'longitude', 'review_year',
#        'review_month', 'review_day', 'pets', 'room_count', 'room_type',
#        'stay_duration_days', 'submission_device', 'traveler_type',
#        'trip_type'],
#       dtype='object')

# %%
# Смотрим, есть ли у нас различия в столбцах
print('Test - train:', set(test_df.columns) - set(df.columns))
print('Train - test:', set(df.columns) - set(test_df.columns))
# Out:
# Test - train: set()
# Train - test: {'score'}

# %% [markdown]
# ### Заполнение пропусков
#
# Заполним пропуски в новых столбцах

# %%
# Выводим список пропусков в столбцах
pd.DataFrame({
    'train': df.isna().sum(),
    'test': test_df.isna().sum(),
})
# Out:
#                      train      test
# address                  0       0.0
# avg_scoring_rating       0       0.0
# days_since_review        0       0.0
# hotel                    0       0.0
# hotel_review_count       0       0.0
# latitude              2600     668.0
# longitude             2600     668.0
# nationality              0       0.0
# negative_review          0       0.0
# negative_words           0       0.0
# pets                     0       0.0
# positive_review          0       0.0
# positive_words           0       0.0
# review_date              0       0.0
# review_day               0       0.0
# review_month             0       0.0
# review_year              0       0.0
# room_count          401887  100593.0
# room_type            17941    4460.0
# score                    0       NaN
# stay_duration_days     152      40.0
# submission_device   166097   41845.0
# tags                     0       0.0
# total_reviews            0       0.0
# traveler_type            5       1.0
# trip_type            12022    2986.0

# %%
# Заполняем пропуски в тренировочном датасете
df['room_type'] = df['room_type'].fillna('unknown')
df['room_count'] = df['room_count'].fillna('unknown')
df['trip_type'] = df['trip_type'].fillna('unknown')
df['submission_device'] = df['submission_device'].fillna('desktop')

# Аналогичным образом заполняем пропуски в тестовом датасете
test_df['room_type'] = test_df['room_type'].fillna('unknown')
test_df['room_count'] = test_df['room_count'].fillna('unknown')
test_df['trip_type'] = test_df['trip_type'].fillna('unknown')
test_df['submission_device'] = test_df['submission_device'].fillna('desktop')

# %%
# Проверяем, корректно ли мы все заполнили
pd.DataFrame({
    'train': df.isna().sum(),
    'test': test_df.isna().sum(),
})
# Out:
#                     train   test
# address                 0    0.0
# avg_scoring_rating      0    0.0
# days_since_review       0    0.0
# hotel                   0    0.0
# hotel_review_count      0    0.0
# latitude             2600  668.0
# longitude            2600  668.0
# nationality             0    0.0
# negative_review         0    0.0
# negative_words          0    0.0
# pets                    0    0.0
# positive_review         0    0.0
# positive_words          0    0.0
# review_date             0    0.0
# review_day              0    0.0
# review_month            0    0.0
# review_year             0    0.0
# room_count              0    0.0
# room_type               0    0.0
# score                   0    NaN
# stay_duration_days    152   40.0
# submission_device       0    0.0
# tags                    0    0.0
# total_reviews           0    0.0
# traveler_type           5    1.0
# trip_type               0    0.0

# %% [markdown]
# ## Корреляционный анализ
# Проведем корреляционный анализ столбцов с таргетом

# %%
df_processed = df.drop(['review_date', 'tags', 'latitude', 'longitude', 'address'], axis=1).copy()
test_df_processed = test_df.drop(['review_date', 'tags', 'latitude', 'longitude', 'address'], axis=1).copy()
df_processed
# Out:
#         avg_scoring_rating                                            hotel  \
# 0                      170  DoubleTree by Hilton Hotel Amsterdam NDSM Wharf
# 1                      114                            Savoy Hotel Amsterdam
# 2                     1195                      Park Plaza London Riverbank
# 3                      111                   Palais Hansen Kempinski Vienna
# 4                      147                              Catalonia Rigoletto
# ...                    ...                                              ...
# 412585                 764                  Club Quarters Hotel Gracechurch
# 412586                2623             Park Plaza Westminster Bridge London
# 412587                 444                             Park Lane Mews Hotel
# 412588                 623                        Apex City Of London Hotel
# 412589                 255    DoubleTree by Hilton Hotel London Marble Arch
#
#              nationality                                    negative_review  \
# 0        United Kingdom    Too far from attractions Had to use ferry to ...
# 1              Malaysia    Staff should handle customer document during ...
# 2        United Kingdom    The hot breakfast could have been fresher tas...
# 3                  Oman    You have to pay the full amount before arrivi...
# 4        United Kingdom                                            All Good
# ...                  ...                                                ...
# 412585          Belgium    Most of the coffee shops around the hotel are...
# 412586   United Kingdom                                Bar rather expensive
# 412587   United Kingdom    Lack of ironing facilities Asked for iron to ...
# 412588   United Kingdom    Having stayed at this hotel a number of times...
# 412589         Malaysia    The mattress was too soft Both of us are pron...
#
#         negative_words  hotel_review_count  \
# 0                   72                1593
# 1                  246                 995
# 2                   19                4684
# 3                   14                 865
# 4                    3                1562
# ...                ...                 ...
# 412585              24                2996
# 412586               4               12158
# 412587              21                2061
# 412588              29                2750
# 412589              22                1290
#
#                                           positive_review  positive_words  \
# 0                 Staff were very helpful Good breakfast                8
# 1        Very clean and cozy room Friendly and helpful...              41
# 2        The room was to a high standard The staff wer...              19
# 3                               Everything was excellent                5
# 4        The location was excellent for visiting the N...              11
# ...                                                   ...             ...
# 412585   Good location at walking distance to metro st...              75
# 412586   Location and quality of the go Room was a gre...              17
# 412587           Excellent location comfortable and clean               6
# 412588   All the staff where very friendly helpful Hot...              41
# 412589                                        No Positive               0
#
#         total_reviews  score  ...  review_year  review_month  review_day  \
# 0                   1    5.4  ...         2017             4          17
# 1                   1    9.6  ...         2016             5          26
# 2                   3    8.8  ...         2016            12           4
# 3                  21   10.0  ...         2017             4          30
# 4                   1    9.2  ...         2017             1          22
# ...               ...    ...  ...          ...           ...         ...
# 412585             28    9.2  ...         2017             3          31
# 412586              4   10.0  ...         2017             5          19
# 412587              1    7.9  ...         2015            12           7
# 412588              4    8.3  ...         2017             4          16
# 412589              5    7.9  ...         2016             6          14
#
#         pets  room_count               room_type stay_duration_days  \
# 0        0.0     unknown        Queen Guest Room                3.0
# 1        0.0     unknown       Small Double Room                1.0
# 2        0.0     unknown    Superior Double Room                2.0
# 3        0.0     unknown             Deluxe Room                4.0
# 4        0.0     unknown     Double or Twin Room                2.0
# ...      ...         ...                     ...                ...
# 412585   0.0     unknown        Small Queen Room                1.0
# 412586   0.0     unknown           Studio Triple                2.0
# 412587   0.0     unknown             Double Room                1.0
# 412588   0.0     unknown  City King or Twin Room                1.0
# 412589   0.0     unknown     Standard Queen Room                3.0
#
#         submission_device               traveler_type      trip_type
# 0                  mobile                      Couple   Leisure trip
# 1                  mobile                      Couple   Leisure trip
# 2                  mobile               Solo traveler  Business trip
# 3                  mobile                      Couple   Leisure trip
# 4                 desktop  Family with young children   Leisure trip
# ...                   ...                         ...            ...
# 412585            desktop                      Couple   Leisure trip
# 412586             mobile  Family with young children   Leisure trip
# 412587            desktop               Solo traveler  Business trip
# 412588             mobile                      Couple   Leisure trip
# 412589            desktop                      Couple   Leisure trip
#
# [412236 rows x 21 columns]

# %%
#todo раскомментировать в финальной версии

# plt.figure(figsize=(17, 10))
#
# # Определяем столбцы с числовыми значениями
# ic = ['avg_scoring_rating', 'negative_words', 'hotel_review_count', 'positive_words', 'total_reviews',
#       'days_since_review', 'review_year', 'review_month', 'review_day', 'pets', 'stay_duration_days', 'score']
#
# # Рисуем матрицу корреляции
# sns.heatmap(df_processed.drop(['negative_review', 'positive_review'], axis=1).phik_matrix(interval_cols=ic),
#             annot=True, cmap='Greens',
#             mask=np.triu(np.ones_like(
#                 df_processed.drop(['negative_review', 'positive_review'], axis=1).phik_matrix(interval_cols=ic),
#                 dtype=bool)))
#
# plt.show()

# %%
cols_to_drop = ['avg_scoring_rating',
                'hotel_review_count', 'total_reviews', 'days_since_review',
                'review_year', 'review_month', 'review_day',
                'pets', 'room_count', 'stay_duration_days', 'submission_device',
                'trip_type', 'traveler_type']

# %%
# Удаляем столбцы с корреляцией ниже 0.1
df_processed = df_processed.drop(cols_to_drop, axis=1)

test_df_processed = test_df_processed.drop(cols_to_drop, axis=1)

# %%
#todo раскомментировать в финальной версии

# # Заново рисуем матрицу корреляции
# plt.figure(figsize=(17, 10))
#
# # Определяем столбцы с числовыми значениями
# ic = ['negative_words', 'positive_words', 'score']
#
# # Рисуем матрицу корреляции
# sns.heatmap(df_processed.drop(['negative_review', 'positive_review'], axis=1).phik_matrix(interval_cols=ic),
#             annot=True, cmap='Greens',
#             mask=np.triu(np.ones_like(
#                 df_processed.drop(['negative_review', 'positive_review'], axis=1).phik_matrix(interval_cols=ic),
#                 dtype=bool)))
#
# plt.show()

# %%
# Смотрим, есть ли у нас различия в столбцах
print('Test - train:', set(test_df_processed.columns) - set(df_processed.columns))
print('Train - test:', set(df_processed.columns) - set(test_df_processed.columns))
# Out:
# Test - train: set()
# Train - test: {'score'}

# %% [markdown]
# ## Feature engineering
#
# Добавим новые признаки и преобразуем уже существующие

# %%
# Смотрим, больше у нас отрицательных или положительных слов
df_processed['neg_words_supremacy'] = df_processed.apply(
    lambda row: 1 if row['negative_words'] > row['positive_words'] else 0,
    axis=1)

test_df_processed['neg_words_supremacy'] = test_df_processed.apply(
    lambda row: 1 if row['negative_words'] > row['positive_words'] else 0,
    axis=1)

# # Смотрим, больше у нас отрицательных или положительных слов
# df_processed['pos_words_supremacy'] = df_processed.apply(
#     lambda row: 1 if row['negative_words'] < row['positive_words'] else 0,
#     axis=1)
#
# test_df_processed['pos_words_supremacy'] = test_df_processed.apply(
#     lambda row: 1 if row['negative_words'] < row['positive_words'] else 0,
#     axis=1)

df_processed
# Out:
#                                                   hotel       nationality  \
# 0       DoubleTree by Hilton Hotel Amsterdam NDSM Wharf   United Kingdom
# 1                                 Savoy Hotel Amsterdam         Malaysia
# 2                           Park Plaza London Riverbank   United Kingdom
# 3                        Palais Hansen Kempinski Vienna             Oman
# 4                                   Catalonia Rigoletto   United Kingdom
# ...                                                 ...               ...
# 412585                  Club Quarters Hotel Gracechurch          Belgium
# 412586             Park Plaza Westminster Bridge London   United Kingdom
# 412587                             Park Lane Mews Hotel   United Kingdom
# 412588                        Apex City Of London Hotel   United Kingdom
# 412589    DoubleTree by Hilton Hotel London Marble Arch         Malaysia
#
#                                           negative_review  negative_words  \
# 0        Too far from attractions Had to use ferry to ...              72
# 1        Staff should handle customer document during ...             246
# 2        The hot breakfast could have been fresher tas...              19
# 3        You have to pay the full amount before arrivi...              14
# 4                                                All Good               3
# ...                                                   ...             ...
# 412585   Most of the coffee shops around the hotel are...              24
# 412586                               Bar rather expensive               4
# 412587   Lack of ironing facilities Asked for iron to ...              21
# 412588   Having stayed at this hotel a number of times...              29
# 412589   The mattress was too soft Both of us are pron...              22
#
#                                           positive_review  positive_words  \
# 0                 Staff were very helpful Good breakfast                8
# 1        Very clean and cozy room Friendly and helpful...              41
# 2        The room was to a high standard The staff wer...              19
# 3                               Everything was excellent                5
# 4        The location was excellent for visiting the N...              11
# ...                                                   ...             ...
# 412585   Good location at walking distance to metro st...              75
# 412586   Location and quality of the go Room was a gre...              17
# 412587           Excellent location comfortable and clean               6
# 412588   All the staff where very friendly helpful Hot...              41
# 412589                                        No Positive               0
#
#         score               room_type  neg_words_supremacy
# 0         5.4        Queen Guest Room                    1
# 1         9.6       Small Double Room                    1
# 2         8.8    Superior Double Room                    0
# 3        10.0             Deluxe Room                    1
# 4         9.2     Double or Twin Room                    0
# ...       ...                     ...                  ...
# 412585    9.2        Small Queen Room                    0
# 412586   10.0           Studio Triple                    0
# 412587    7.9             Double Room                    1
# 412588    8.3  City King or Twin Room                    0
# 412589    7.9     Standard Queen Room                    1
#
# [412236 rows x 9 columns]

# %%
def evaluate_level(col_value):
    if col_value > 50:
        return 'high'
    if col_value > 20:
        return 'medium'
    if col_value == 0:
        return 'none'
    return 'low'

# %%
df_processed['negative_words_level'] = df_processed['negative_words'].apply(evaluate_level)
df_processed['positive_words_level'] = df_processed['positive_words'].apply(evaluate_level)

test_df_processed['negative_words_level'] = test_df_processed['negative_words'].apply(evaluate_level)
test_df_processed['positive_words_level'] = test_df_processed['positive_words'].apply(evaluate_level)

# %%
# Приводим столбцы в тренировочном датасете к нужному типу данных
df_processed['hotel'] = df_processed['hotel'].astype('category')
df_processed['nationality'] = df_processed['nationality'].astype('category')
df_processed['negative_review'] = df_processed['negative_review'].astype('category')
df_processed['positive_review'] = df_processed['positive_review'].astype('category')
df_processed['room_type'] = df_processed['room_type'].astype('category')
df_processed['neg_words_supremacy'] = df_processed['neg_words_supremacy'].astype('category')
df_processed['negative_words_level'] = df_processed['negative_words_level'].astype('category')
df_processed['positive_words_level'] = df_processed['positive_words_level'].astype('category')

# Приводим столбцы в тестовом датасете к нужному типу данных
test_df_processed['hotel'] = test_df_processed['hotel'].astype('category')
test_df_processed['nationality'] = test_df_processed['nationality'].astype('category')
test_df_processed['negative_review'] = test_df_processed['negative_review'].astype('category')
test_df_processed['positive_review'] = test_df_processed['positive_review'].astype('category')
test_df_processed['room_type'] = test_df_processed['room_type'].astype('category')
test_df_processed['neg_words_supremacy'] = test_df_processed['neg_words_supremacy'].astype('category')
test_df_processed['negative_words_level'] = test_df_processed['negative_words_level'].astype('category')
test_df_processed['positive_words_level'] = test_df_processed['positive_words_level'].astype('category')

# %% [markdown]
# ### Токенизация

# %%
# Модель all-MiniLM-L6-v2 работает быстро и требует мало ресурсов
model = SentenceTransformer('all-MiniLM-L6-v2')


def encode_reviews(df, column, model, batch_size=1000):
    embeddings = []
    total_batches = len(df) // batch_size + 1

    for i in tqdm(range(0, len(df), batch_size), desc=f"Encoding {column}"):
        batch = df[column].iloc[i:i + batch_size]
        batch_embeddings = model.encode(
            batch.tolist(),
            device='mps' if torch.backends.mps.is_available() else 'cpu'
        )
        embeddings.append(batch_embeddings)

    return np.concatenate(embeddings, axis=0)

# %%
# Преобразование столбцов в тренировочном датасете
train_neg_embeddings = encode_reviews(df_processed, 'negative_review', model)
train_pos_embeddings = encode_reviews(df_processed, 'positive_review', model)

# Преобразование столбцов в тестовом датасете
test_neg_embeddings = encode_reviews(test_df_processed, 'negative_review', model)
test_pos_embeddings = encode_reviews(test_df_processed, 'positive_review', model)
# Out:
# Encoding negative_review:   0%|          | 0/413 [00:00<?, ?it/s]
# Encoding positive_review:   0%|          | 0/413 [00:00<?, ?it/s]
# Encoding negative_review:   0%|          | 0/104 [00:00<?, ?it/s]
# Encoding positive_review:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
# Преобразование тренировочных эмбеддингов в DataFrame
train_neg_emb_df = pd.DataFrame(train_neg_embeddings,
                                columns=[f'neg_emb_{i}' for i in range(train_neg_embeddings.shape[1])])
train_pos_emb_df = pd.DataFrame(train_pos_embeddings,
                                columns=[f'pos_emb_{i}' for i in range(train_pos_embeddings.shape[1])])

# Преобразование тестовых эмбеддингов в DataFrame
test_neg_emb_df = pd.DataFrame(test_neg_embeddings,
                               columns=[f'neg_emb_{i}' for i in range(test_neg_embeddings.shape[1])])
test_pos_emb_df = pd.DataFrame(test_pos_embeddings,
                               columns=[f'pos_emb_{i}' for i in range(test_pos_embeddings.shape[1])])

# %%
# Сброс индекса для корректного объединения тренировочного датасета
df_processed.reset_index(drop=True, inplace=True)
train_df_combined = pd.concat([df_processed, train_neg_emb_df, train_pos_emb_df], axis=1)

# Сброс индекса для корректного объединения тестового датасета
test_df_processed.reset_index(drop=True, inplace=True)
test_df_combined = pd.concat([test_df_processed, test_neg_emb_df, test_pos_emb_df], axis=1)

# %%
train_df_combined = train_df_combined

# %% [markdown]
# ## Сохранение данных для использования при обучении

# %%
train_df_combined.to_csv('data/train_df_processed.csv', index=False)
test_df_combined.to_csv('data/test_df_processed.csv', index=False)
